# %% [markdown]
# <a href="https://colab.research.google.com/github/AlejaCruzR/Challenge_Alura_Store_AleCruz/blob/main/AluraStoreLatam_AleCruz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda.tail()
# Out:
#            Producto Categoría del Producto     Precio  Costo de envío  \
# 2354      Iphone 15           Electrónicos  1284400.0         66600.0
# 2355      Impresora           Electrónicos   282800.0         15300.0
# 2356  Juego de mesa               Juguetes   122900.0          7200.0
# 2357       Cama box                Muebles   691300.0         35000.0
# 2358     Smartwatch           Electrónicos   195000.0          8600.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 2354      15/11/2021  Izabela de León        Medellín             1
# 2355      18/03/2023    Lucas Olivera          Bogotá             5
# 2356      06/07/2021    Lucas Olivera            Cali             5
# 2357      02/05/2022      Pedro Gomez           Pasto             1
# 2358      18/06/2022    Felipe Santos            Cali             4
#
#           Método de pago  Cantidad de cuotas      lat       lon
# 2354               Nequi                   1  6.25184 -75.56359
# ...

# %%
type(tienda)
# Out:
# pandas.core.frame.DataFrame

# %%
tienda.shape
# Out:
# (2359, 12)

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda[['Producto', 'Categoría del Producto']]
# Out:
#                Producto Categoría del Producto
# 0     Asistente virtual           Electrónicos
# 1       Mesa de comedor                Muebles
# 2         Juego de mesa               Juguetes
# 3            Microondas      Electrodomésticos
# 4      Silla de oficina                Muebles
# ...                 ...                    ...
# 2354          Iphone 15           Electrónicos
# 2355          Impresora           Electrónicos
# 2356      Juego de mesa               Juguetes
# 2357           Cama box                Muebles
# 2358         Smartwatch           Electrónicos
#
# [2359 rows x 2 columns]

# %%
tienda[['Precio','Costo de envío']]
# Out:
#          Precio  Costo de envío
# 0      164300.0          6900.0
# 1      192300.0          8400.0
# 2      209600.0         15900.0
# 3      757500.0         41000.0
# 4      335200.0         20200.0
# ...         ...             ...
# 2354  1284400.0         66600.0
# 2355   282800.0         15300.0
# 2356   122900.0          7200.0
# 2357   691300.0         35000.0
# 2358   195000.0          8600.0
#
# [2359 rows x 2 columns]

# %%
tienda[['Fecha de Compra', 'Lugar de Compra']]
# Out:
#      Fecha de Compra Lugar de Compra
# 0         16/01/2021          Bogotá
# 1         18/05/2022        Medellín
# 2         15/03/2021       Cartagena
# 3         03/05/2022            Cali
# 4         07/11/2020        Medellín
# ...              ...             ...
# 2354      15/11/2021        Medellín
# 2355      18/03/2023          Bogotá
# 2356      06/07/2021            Cali
# 2357      02/05/2022           Pasto
# 2358      18/06/2022            Cali
#
# [2359 rows x 2 columns]

# %%
tienda[['Calificación']]
# Out:
#       Calificación
# 0                4
# 1                1
# 2                1
# 3                4
# 4                5
# ...            ...
# 2354             1
# 2355             5
# 2356             5
# 2357             1
# 2358             4
#
# [2359 rows x 1 columns]

# %%
tienda[['Método de pago', 'Cantidad de cuotas']]
# Out:
#           Método de pago  Cantidad de cuotas
# 0     Tarjeta de crédito                   8
# 1     Tarjeta de crédito                   4
# 2     Tarjeta de crédito                   1
# 3                  Nequi                   1
# 4                  Nequi                   1
# ...                  ...                 ...
# 2354               Nequi                   1
# 2355               Nequi                   1
# 2356  Tarjeta de crédito                   4
# 2357  Tarjeta de crédito                   2
# 2358  Tarjeta de crédito                   1
#
# [2359 rows x 2 columns]

# %%
tienda[['lat','lon']]
# Out:
#            lat       lon
# 0      4.60971 -74.08175
# 1      6.25184 -75.56359
# 2     10.39972 -75.51444
# 3      3.43722 -76.52250
# 4      6.25184 -75.56359
# ...        ...       ...
# 2354   6.25184 -75.56359
# 2355   4.60971 -74.08175
# 2356   3.43722 -76.52250
# 2357   1.21361 -77.28111
# 2358   3.43722 -76.52250
#
# [2359 rows x 2 columns]

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda2.tail()
# Out:
#               Producto   Categoría del Producto     Precio  Costo de envío  \
# 2354      Set de ollas  Artículos para el hogar   140300.0          8100.0
# 2355  Lavadora de ropa        Electrodomésticos  1220100.0         65200.0
# 2356        Microondas        Electrodomésticos   797900.0         42900.0
# 2357         Iphone 15             Electrónicos  2224300.0        116600.0
# 2358         Bicicleta     Deportes y diversión   551000.0         27500.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 2354      04/12/2022  Ángel Rodriguez    Barranquilla             5
# 2355      09/02/2020   Santiago Silva          Bogotá             4
# 2356      27/09/2022   Blanca Ramirez          Bogotá             5
# 2357      21/04/2022   Juan Fernandez        Medellín             5
# 2358      03/09/2022    Maria Alfonso        Medellín             4
#
#           Método de pago  Cantidad de cuotas       lat       lon
# ...

# %%
tienda2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda2.shape
# Out:
# (2359, 12)

# %%
tienda2[['Producto', 'Categoría del Producto']]
# Out:
#               Producto   Categoría del Producto
# 0     Silla de oficina                  Muebles
# 1            Pandereta   Instrumentos musicales
# 2            Cama king                  Muebles
# 3            Cama king                  Muebles
# 4     Silla de oficina                  Muebles
# ...                ...                      ...
# 2354      Set de ollas  Artículos para el hogar
# 2355  Lavadora de ropa        Electrodomésticos
# 2356        Microondas        Electrodomésticos
# 2357         Iphone 15             Electrónicos
# 2358         Bicicleta     Deportes y diversión
#
# [2359 rows x 2 columns]

# %%
tienda2[['Precio','Costo de envío']]
# Out:
#          Precio  Costo de envío
# 0      283600.0         15300.0
# 1       76800.0          2300.0
# 2      443300.0         23800.0
# 3      906200.0         46400.0
# 4      397800.0         19400.0
# ...         ...             ...
# 2354   140300.0          8100.0
# 2355  1220100.0         65200.0
# 2356   797900.0         42900.0
# 2357  2224300.0        116600.0
# 2358   551000.0         27500.0
#
# [2359 rows x 2 columns]

# %%
tienda2[['Fecha de Compra', 'Lugar de Compra']]
# Out:
#      Fecha de Compra Lugar de Compra
# 0         04/08/2021        Medellín
# 1         26/11/2020        Medellín
# 2         22/10/2021         Pereira
# 3         04/05/2022            Cali
# 4         26/02/2022          Bogotá
# ...              ...             ...
# 2354      04/12/2022    Barranquilla
# 2355      09/02/2020          Bogotá
# 2356      27/09/2022          Bogotá
# 2357      21/04/2022        Medellín
# 2358      03/09/2022        Medellín
#
# [2359 rows x 2 columns]

# %%
tienda2[['Calificación']]
# Out:
#       Calificación
# 0                1
# 1                3
# 2                5
# 3                5
# 4                4
# ...            ...
# 2354             5
# 2355             4
# 2356             5
# 2357             5
# 2358             4
#
# [2359 rows x 1 columns]

# %%
tienda2[['Método de pago', 'Cantidad de cuotas']]
# Out:
#           Método de pago  Cantidad de cuotas
# 0                  Nequi                   1
# 1     Tarjeta de crédito                   4
# 2     Tarjeta de crédito                  10
# 3     Tarjeta de crédito                  10
# 4     Tarjeta de crédito                   3
# ...                  ...                 ...
# 2354  Tarjeta de crédito                   2
# 2355  Tarjeta de crédito                   5
# 2356               Nequi                   1
# 2357  Tarjeta de crédito                   2
# 2358  Tarjeta de crédito                   1
#
# [2359 rows x 2 columns]

# %%
tienda2[['Método de pago', 'Cantidad de cuotas']]
# Out:
#           Método de pago  Cantidad de cuotas
# 0                  Nequi                   1
# 1     Tarjeta de crédito                   4
# 2     Tarjeta de crédito                  10
# 3     Tarjeta de crédito                  10
# 4     Tarjeta de crédito                   3
# ...                  ...                 ...
# 2354  Tarjeta de crédito                   2
# 2355  Tarjeta de crédito                   5
# 2356               Nequi                   1
# 2357  Tarjeta de crédito                   2
# 2358  Tarjeta de crédito                   1
#
# [2359 rows x 2 columns]

# %%
tienda2[['lat','lon']]
# Out:
#            lat       lon
# 0      6.25184 -75.56359
# 1      6.25184 -75.56359
# 2      4.81333 -75.69611
# 3      3.43722 -76.52250
# 4      4.60971 -74.08175
# ...        ...       ...
# 2354  10.96854 -74.78132
# 2355   4.60971 -74.08175
# 2356   4.60971 -74.08175
# 2357   6.25184 -75.56359
# 2358   6.25184 -75.56359
#
# [2359 rows x 2 columns]

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda3.tail()
# Out:
#                      Producto Categoría del Producto    Precio  \
# 2354  Dashboards con Power BI                 Libros   26700.0
# 2355  Dashboards con Power BI                 Libros   31800.0
# 2356         Silla de oficina                Muebles  477100.0
# 2357           Mesa de centro                Muebles  123100.0
# 2358      Modelado predictivo                 Libros   63400.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 2354          2100.0      21/10/2022  Ángel Rodriguez          Bogotá
# 2355          2200.0      23/06/2022   Blanca Ramirez         Pereira
# 2356         25600.0      19/02/2023    Camila Rivera       Cartagena
# 2357          4700.0      19/09/2021   Blanca Ramirez          Bogotá
# 2358          9400.0      24/05/2022  Mariana Herrera        Medellín
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 2354             5  Tarjeta de crédito                   1   4.60971 -74.08175
# ...

# %%
tienda3['Categoría del Producto'].unique()
# Out:
# array(['Electrodomésticos', 'Muebles', 'Instrumentos musicales',
#        'Deportes y diversión', 'Electrónicos', 'Juguetes',
#        'Artículos para el hogar', 'Libros'], dtype=object)

# %%
tienda3.shape
# Out:
# (2359, 12)

# %%
tienda3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %%
tienda4.tail()
# Out:
#                 Producto   Categoría del Producto    Precio  Costo de envío  \
# 2353     Mesa de comedor                  Muebles  227700.0         12600.0
# 2354    Silla de oficina                  Muebles  342000.0         18600.0
# 2355        Vaso térmico     Deportes y diversión   36700.0          2400.0
# 2356        Set de ollas  Artículos para el hogar  151800.0          8300.0
# 2357  Cuerda para saltar     Deportes y diversión   11200.0          1300.0
#
#      Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 2353      12/02/2020   Camila Rivera        Medellín             5
# 2354      17/05/2022   Felipe Santos     Bucaramanga             5
# 2355      03/05/2022   Camila Rivera          Bogotá             5
# 2356      15/06/2020  Blanca Ramirez            Cali             5
# 2357      17/11/2021   Felipe Santos          Bogotá             5
#
#           Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
tienda4.shape
# Out:
# (2358, 12)

# %%
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %%
# !git clone https://github.com/sw98cs/ChalengeAluraStoreClaudia.git
# Out:
# Cloning into 'ChalengeAluraStoreClaudia'...
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ##1.1 Datos en cifras - Ingresos totales de las tiendas

# %%
"""
En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna
Precio de cada conjunto de datos de la tienda para estimar los ingresos.
"""

total_precio_tienda1 = tienda['Precio'].sum()
print(f"Total de precios para tienda 1: {total_precio_tienda1}")

total_precio_tienda2 = tienda2['Precio'].sum()
print(f"Total de precios para tienda 2: {total_precio_tienda2}")

total_precio_tienda3 = tienda3['Precio'].sum()
print(f"Total de precios para tienda 3: {total_precio_tienda3}")

total_precio_tienda4 = tienda4['Precio'].sum()
print(f"Total de precios para tienda 4: {total_precio_tienda4}")
# Out:
# Total de precios para tienda 1: 1150880400.0
# Total de precios para tienda 2: 1116343500.0
# Total de precios para tienda 3: 1098019600.0
# Total de precios para tienda 4: 1038375700.0

# %% [markdown]
# ##1.2 Graficos - Barras y Pastel - Tienda 4 menores ingresos que las demas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

totales_tiendas = {
    'Tienda 1': total_precio_tienda1,
    'Tienda 2': total_precio_tienda2,
    'Tienda 3': total_precio_tienda3,
    'Tienda 4': total_precio_tienda4
}

# Convertir a DataFrame para facilitar la visualización
df_totales = pd.DataFrame(list(totales_tiendas.items()), columns=['Tienda', 'Total Precio'])

plt.figure(figsize=(10, 6))
sns.barplot(x='Tienda', y='Total Precio', data=df_totales, palette='viridis')
plt.suptitle('Comparación de ingresos Totales por Tienda')
plt.title('La tienda 4 la que menos ingresos genera', fontsize=10, y=0.94, color='red')
plt.xlabel('Tienda')
plt.ylabel('Total de Ingresos')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='y') # Evita la notación científica en el eje Y
plt.ylim(600000000, 1200000000)
plt.savefig('comparacion_ingresos_Gbarra.png', dpi=300,bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-65361737.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Tienda', y='Total Precio', data=df_totales, palette='viridis')

# %%
df_totales = pd.DataFrame(list(totales_tiendas.items()), columns=['Tienda', 'Total Precio'])

paleta = ['#3C2C73', '#2C6173', '#3A9882', '#46B955']
plt.figure(figsize=(6, 6))
wedges, texts, autotexts = plt.pie(
    df_totales['Total Precio'],
    labels=df_totales['Tienda'],
    autopct='%1.1f%%',     # para mostrar porcentaje
    startangle=90,
    colors=paleta
)

for at in autotexts:
    at.set_color('white')
    at.set_fontweight('bold')

plt.suptitle('Proporción de Ingresos Totales por Tienda')
plt.title('La tienda 4 es la que menos ingresos genera', fontsize=10, color='red')
plt.tight_layout()
plt.savefig('comparacion_ingresos_Gpastel.png', dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ## 2.1 Datos en cifras - Categorías de productos más y menos vendidas.

# %%
"""
En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría
y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.
"""

ventas_categoria_tienda1 = tienda.groupby('Categoría del Producto')['Precio'].sum().reset_index()
print("Ventas por Categoría - Tienda 1:")
print(ventas_categoria_tienda1)

ventas_categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Precio'].sum().reset_index()
print("\nVentas por Categoría - Tienda 2:")
print(ventas_categoria_tienda2)

ventas_categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Precio'].sum().reset_index()
print("\nVentas por Categoría - Tienda 3:")
print(ventas_categoria_tienda3)

ventas_categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Precio'].sum().reset_index()
print("\nVentas por Categoría - Tienda 4:")
print(ventas_categoria_tienda4)
# Out:
# Ventas por Categoría - Tienda 1:
#     Categoría del Producto       Precio
# 0  Artículos para el hogar   12698400.0
# 1     Deportes y diversión   39290000.0
# 2        Electrodomésticos  363685200.0
# 3             Electrónicos  429493500.0
# 4   Instrumentos musicales   91299000.0
# 5                 Juguetes   17995700.0
# 6                   Libros    8784900.0
# 7                  Muebles  187633700.0
#
# Ventas por Categoría - Tienda 2:
#     Categoría del Producto       Precio
# 0  Artículos para el hogar   14746900.0
# 1     Deportes y diversión   34744500.0
# 2        Electrodomésticos  348567800.0
# 3             Electrónicos  410831100.0
# 4   Instrumentos musicales  104990300.0
# 5                 Juguetes   15945400.0
# 6                   Libros   10091200.0
# 7                  Muebles  176426300.0
#
# Ventas por Categoría - Tienda 3:
#     Categoría del Producto       Precio
# 0  Artículos para el hogar   15060000.0
# 1     Deportes y diversión   35593100.0
# ...

# %%
"""
Ordenados de mayor a menor
"""

tienda1_categorias = tienda.groupby('Categoría del Producto')['Precio'].sum().reset_index().sort_values('Precio',ascending=False)
print('Ventas por Categoría - Tienda 1:')
print(tienda1_categorias)

tienda2_categorias = tienda2.groupby('Categoría del Producto')['Precio'].sum().reset_index().sort_values('Precio',ascending=False)
print('Ventas por Categoría - Tienda 1:')
print(tienda2_categorias)

tienda3_categorias = tienda3.groupby('Categoría del Producto')['Precio'].sum().reset_index().sort_values('Precio',ascending=False)
print('Ventas por Categoría - Tienda 1:')
print(tienda3_categorias)

tienda4_categorias = tienda4.groupby('Categoría del Producto')['Precio'].sum().reset_index().sort_values('Precio',ascending=False)
print('Ventas por Categoría - Tienda 1:')
print(tienda4_categorias)
# Out:
# Ventas por Categoría - Tienda 1:
#     Categoría del Producto       Precio
# 3             Electrónicos  429493500.0
# 2        Electrodomésticos  363685200.0
# 7                  Muebles  187633700.0
# 4   Instrumentos musicales   91299000.0
# 1     Deportes y diversión   39290000.0
# 5                 Juguetes   17995700.0
# 0  Artículos para el hogar   12698400.0
# 6                   Libros    8784900.0
# Ventas por Categoría - Tienda 1:
#     Categoría del Producto       Precio
# 3             Electrónicos  410831100.0
# 2        Electrodomésticos  348567800.0
# 7                  Muebles  176426300.0
# 4   Instrumentos musicales  104990300.0
# 1     Deportes y diversión   34744500.0
# 5                 Juguetes   15945400.0
# 0  Artículos para el hogar   14746900.0
# 6                   Libros   10091200.0
# Ventas por Categoría - Tienda 1:
#     Categoría del Producto       Precio
# 3             Electrónicos  410775800.0
# 2        Electrodomésticos  329237900.0
# ...

# %% [markdown]
# ## 2.2 Graficos - Barras apiladas y barras de cada tienda

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Renombrar las columnas 'Precio' a los nombres de las tiendas para facilitar la combinación
t1 = ventas_categoria_tienda1.rename(columns={'Precio': 'Tienda 1'})
t2 = ventas_categoria_tienda2.rename(columns={'Precio': 'Tienda 2'})
t3 = ventas_categoria_tienda3.rename(columns={'Precio': 'Tienda 3'})
t4 = ventas_categoria_tienda4.rename(columns={'Precio': 'Tienda 4'})
# Unir por categoria cada tienda
df_totales_categorias = t1.merge(t2, on='Categoría del Producto') \
                          .merge(t3, on='Categoría del Producto') \
                          .merge(t4, on='Categoría del Producto')
# Establecer 'Categoría del Producto' como índice
df_totales_categorias = df_totales_categorias.set_index('Categoría del Producto')
df_tiendas = df_totales_categorias.T    # <- ESTA es la vuelta importante

# 5. Calculamos proporción por tienda (por fila ahora)
df_prop_tiendas = df_tiendas.div(df_tiendas.sum(axis=1), axis=0)
orden_categorias = df_prop_tiendas.sum(axis=0).sort_values(ascending=False).index


# esto te da un Index con las categorías ordenadas de menor a mayor
# 2. reordenar el dataframe con ese orden de columnas
df_prop_tiendas_ordenado = df_prop_tiendas[orden_categorias]
# 3. graficar ya ordenado
ax = df_prop_tiendas_ordenado.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 10)
)

plt.title('Proporción de Ingresos por Tienda y Categoría (ordenado)')
plt.xlabel('Tiendas')
plt.ylabel('Proporción de Ingresos')
plt.xticks(rotation=0)
plt.legend(title='Categorías', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Renombrar las columnas 'Precio' a los nombres de las tiendas para facilitar la combinación
t1 = ventas_categoria_tienda1.rename(columns={'Precio': 'Tienda 1'})
t2 = ventas_categoria_tienda2.rename(columns={'Precio': 'Tienda 2'})
t3 = ventas_categoria_tienda3.rename(columns={'Precio': 'Tienda 3'})
t4 = ventas_categoria_tienda4.rename(columns={'Precio': 'Tienda 4'})
# Unir por categoria cada tienda
df_totales_categorias = t1.merge(t2, on='Categoría del Producto') \
                          .merge(t3, on='Categoría del Producto') \
                          .merge(t4, on='Categoría del Producto')

# 3. categoría como índice
df_totales_categorias = df_totales_categorias.set_index('Categoría del Producto')

# 4. Voltear: filas = tiendas, columnas = categorías
df_tiendas = df_totales_categorias.T   # <-- AQUÍ están los valores reales

# 5. (opcional) ordenar las categorías por total de ventas
orden_categorias = df_tiendas.sum(axis=0).sort_values(ascending=False).index
df_tiendas_ordenado = df_tiendas[orden_categorias]

# 3. graficar ya ordenado
ax = df_tiendas_ordenado.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 10)
)

plt.title('Proporción de Ingresos por Tienda y Categoría (ordenado)')
plt.xlabel('Tiendas')
plt.ylabel('Proporción de ingresos')
plt.xticks(rotation=0)
plt.legend(title='Categorías', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.savefig('proporcion_ingresos_Gbarraagrup.png', dpi=300,bbox_inches='tight')
plt.show()

# %%
# ventas_categoria_tienda1.plot(kind='bar', figsize=(12,8), color='orange')

# La línea original causaba un ValueError porque se intentaba crear un DataFrame con dos columnas
# a partir de una única serie de datos.
# df_totales_tienda1Cat = pd.DataFrame(list(tienda['Categoría del Producto']), columns=['Categoría del Producto', 'Total Precio'])

plt.figure(figsize=(10, 6))
sns.barplot(x='Categoría del Producto', y='Precio', data=tienda1_categorias, color='#3C2C73')
plt.title('Comparación de Ingresos Totales por Categoría - Tienda 1')
plt.xlabel('Categoría del Producto')
plt.ylabel('Total de Ingresos')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='y') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Categoría del Producto', y='Precio', data=tienda2_categorias, color='#2C6173')
plt.title('Comparación de Ingresos Totales por Categoría - Tienda 2')
plt.xlabel('Categoría del Producto')
plt.ylabel('Total de Ingresos')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='y') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Categoría del Producto', y='Precio', data=tienda3_categorias, color='#3A9882')
plt.title('Comparación de Ingresos Totales por Categoría - Tienda 3')
plt.xlabel('Categoría del Producto')
plt.ylabel('Total de Ingresos')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='y') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Categoría del Producto', y='Precio', data=tienda4_categorias, color='#46B955')
plt.title('Comparación de Ingresos Totales por Categoría - Tienda 4')
plt.xlabel('Categoría del Producto')
plt.ylabel('Total de Ingresos')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='y') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# ## 3.1 Datos en cifras - Calificaciones promedio de los clientes por tienda.

# %%
"""
En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer
la satisfacción del cliente con los productos vendidos.
"""

# Esta es la general

calif_generalt1 = tienda['Calificación'].mean()
print(f'La calificacion de los clientes promedio de la tienda 1 es: {calif_generalt1}')

calif_generalt2 = tienda2['Calificación'].mean()
print(f'La calificacion de los clientes promedio de la tienda 2 es: {calif_generalt2}')

calif_generalt3 = tienda3['Calificación'].mean()
print(f'La calificacion de los clientes promedio de la tienda 3 es: {calif_generalt3}')

calif_generalt4 = tienda4['Calificación'].mean()
print(f'La calificacion de los clientes promedio de la tienda 4 es: {calif_generalt4}')
# Out:
# La calificacion de los clientes promedio de la tienda 1 es: 3.976685036032217
# La calificacion de los clientes promedio de la tienda 2 es: 4.037303942348453
# La calificacion de los clientes promedio de la tienda 3 es: 4.048325561678677
# La calificacion de los clientes promedio de la tienda 4 es: 3.9957591178965224

# %% [markdown]
# ## 3.2 Graficos - Barras denotando la calificacion de cada tienda y de temperatura de cada categoria de cada tienda

# %%
# Grafico de lo anterior

import matplotlib.pyplot as plt

califs = {
    'Tienda 1': calif_generalt1,
    'Tienda 2': calif_generalt2,
    'Tienda 3': calif_generalt3,
    'Tienda 4': calif_generalt4,
}

# Convertir a DataFrame para facilitar la visualización
df_califgen = pd.DataFrame(list(califs.items()), columns=['Tienda', 'Promedio de Calificacion'])

plt.figure(figsize=(10, 6))
sns.barplot(x='Tienda', y='Promedio de Calificacion', data=df_califgen, palette='viridis')
plt.suptitle('Comparación de promedio de calificacion de cada tienda dada por los clientes')
plt.title('La tienda 4 es una de las peores calificadas', fontsize=10, y=0.94, color='red')
plt.xlabel('Tienda')
plt.ylabel('Promedio de Calificacion')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='y') # Evita la notación científica en el eje Y
plt.ylim(3.8, 4.1)
plt.savefig('comparacion_calificacion_Gbarra.png', dpi=300,bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-2784211520.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Tienda', y='Promedio de Calificacion', data=df_califgen, palette='viridis')

# %% [markdown]
# ### 3.1.1 Datos en cifras - Calificacion de cada categoria de cada tienda

# %%
tienda.groupby('Categoría del Producto')['Calificación'].mean()

calif_categoriat1 = tienda.groupby('Categoría del Producto')['Calificación'].mean().sort_values(ascending=False)
print(f'La calificacion de los clientes por categoria de la tienda 1 es: {calif_categoriat1}')

calif_categoriat2 = tienda2.groupby('Categoría del Producto')['Calificación'].mean().sort_values(ascending=False)
print(f'La calificacion de los clientes por categoria de la tienda 2 es: {calif_categoriat2}')

calif_categoriat3 = tienda3.groupby('Categoría del Producto')['Calificación'].mean().sort_values(ascending=False)
print(f'La calificacion de los clientes por categoria de la tienda 3 es: {calif_categoriat3}')

calif_categoriat4 = tienda4.groupby('Categoría del Producto')['Calificación'].mean().sort_values(ascending=False)
print(f'La calificacion de los clientes por categoria de la tienda 4 es: {calif_categoriat4}')

# %%
tienda.groupby('Categoría del Producto')['Calificación'].mean()

cali_categoriat1 = tienda.groupby('Categoría del Producto')['Calificación'].mean()
print(f'La calificacion de los clientes por categoria de la tienda 1 es: {cali_categoriat1}')

cali_categoriat2 = tienda2.groupby('Categoría del Producto')['Calificación'].mean()
print(f'La calificacion de los clientes por categoria de la tienda 2 es: {cali_categoriat2}')

cali_categoriat3 = tienda3.groupby('Categoría del Producto')['Calificación'].mean()
print(f'La calificacion de los clientes por categoria de la tienda 3 es: {cali_categoriat3}')

cali_categoriat4 = tienda4.groupby('Categoría del Producto')['Calificación'].mean()
print(f'La calificacion de los clientes por categoria de la tienda 4 es: {cali_categoriat4}')

# %% [markdown]
# ### 3.2.1 Graficos - Grafica de calor clasificando cada categoria de cada tienda

# %%
# Un grafico para visualizar

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# armar el dataframe combinado
t1 = tienda.groupby('Categoría del Producto')['Calificación'].mean().rename('Tienda 1')
t2 = tienda2.groupby('Categoría del Producto')['Calificación'].mean().rename('Tienda 2')
t3 = tienda3.groupby('Categoría del Producto')['Calificación'].mean().rename('Tienda 3')
t4 = tienda4.groupby('Categoría del Producto')['Calificación'].mean().rename('Tienda 4')

df = pd.concat([t1, t2, t3, t4], axis=1)

plt.figure(figsize=(10, 6))
sns.heatmap(df, annot=True, cmap='viridis', vmin=3.5, vmax=5)  # ajusta vmin/vmax si quieres
plt.title('Calificación promedio por categoría y tienda')
plt.ylabel('Categoría del producto')
plt.xlabel('Tienda')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ## 4.1 Graficos - Barras laterales de ventas (mayores y menores) de cada tienda

# %%
"""
En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda.
Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.
"""

producto_tienda1 = tienda.groupby('Producto')[['Precio']].sum().sort_values('Precio')
#producto_tienda1.plot(kind='barh', figsize=(12,8), color= 'purple')

plt.figure(figsize=(10, 10))
sns.barplot(y='Producto', x='Precio', data=producto_tienda1, color='#3C2C77')
plt.title('Comparación de venta de cada Producto - Tienda 1')
plt.xlabel('Ventas')
plt.ylabel('Productos')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='x') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
producto_tienda2 = tienda2.groupby('Producto')[['Precio']].sum().sort_values('Precio')
#producto_tienda1.plot(kind='barh', figsize=(12,8), color= 'purple')

plt.figure(figsize=(10, 10))
sns.barplot(y='Producto', x='Precio', data=producto_tienda2, color='#2C6173')
plt.title('Comparación de venta de cada Producto - Tienda 2')
plt.xlabel('Ventas')
plt.ylabel('Productos')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='x') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
producto_tienda3 = tienda3.groupby('Producto')[['Precio']].sum().sort_values('Precio')
#producto_tienda1.plot(kind='barh', figsize=(12,8), color= 'purple')

plt.figure(figsize=(10, 10))
sns.barplot(y='Producto', x='Precio', data=producto_tienda3, color='#3A9882')
plt.title('Comparación de venta de cada Producto - Tienda 3')
plt.xlabel('Ventas')
plt.ylabel('Productos')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='x') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
producto_tienda4 = tienda4.groupby('Producto')[['Precio']].sum().sort_values('Precio')
#producto_tienda1.plot(kind='barh', figsize=(12,8), color= 'purple')

plt.figure(figsize=(10, 10))
sns.barplot(y='Producto', x='Precio', data=producto_tienda4, color='#46B955')
plt.title('Comparación de venta de cada Producto - Tienda 4')
plt.xlabel('Ventas')
plt.ylabel('Productos')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='x') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# ## 5.1 Datos en cifras - Envio promedio por tienda (general)

# %%
"""
En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio,
en el envío de cada tienda.  Sabiendo que el cliente paga el envío.
"""
envio_tienda1 = tienda['Costo de envío'].mean()
print(f"Promedio de costo de envio para tienda 1: {envio_tienda1}")

envio_tienda2 = tienda2['Costo de envío'].mean()
print(f"Promedio de costo de envio para tienda 2: {envio_tienda2}")

envio_tienda3 = tienda3['Costo de envío'].mean()
print(f"Promedio de costo de envio para tienda 3: {envio_tienda3}")

envio_tienda4 = tienda4['Costo de envío'].mean()
print(f"Promedio de costo de envio para tienda 4: {envio_tienda4}")

# %% [markdown]
# ## 5.2 Graficos - Barras promedio de costo de cada tienda

# %%
import matplotlib.pyplot as plt
import seaborn as sns

promedios_costosenvio = {
    'Tienda 1': envio_tienda1,
    'Tienda 2': envio_tienda2,
    'Tienda 3': envio_tienda3,
    'Tienda 4': envio_tienda4
}

# Convertir a DataFrame para facilitar la visualización
df_totales_costoenvio = pd.DataFrame(list(promedios_costosenvio.items()), columns=['Tienda', 'Promedio Costo Envio'])

plt.figure(figsize=(10, 6))
sns.barplot(x='Tienda', y='Promedio Costo Envio', data=df_totales_costoenvio, palette='viridis')
plt.suptitle('Comparación de promedio de costo de envio por Tienda (el cliente paga por el envio)')
plt.title('El cliente paga por el envio', fontsize=10, y=0.94, color='red')
plt.xlabel('Tienda')
plt.ylabel('Promedio de costo de envio')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='y') # Evita la notación científica en el eje Y
plt.savefig('comparacion_costoenvio_Gbarra.png', dpi=300,bbox_inches='tight')
plt.show()

# %%
envios_tienda1 = tienda.groupby('Producto')[['Costo de envío']].mean().sort_values('Costo de envío')

plt.figure(figsize=(10, 10))
sns.barplot(y='Producto', x='Costo de envío', data=envios_tienda1, color='#3C2C73')
plt.title('Comparación de costo de envio promedio de Productos - Tienda 1')
plt.xlabel('Costo de envio')
plt.ylabel('Productos')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='x') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
envios_tienda2 = tienda2.groupby('Producto')[['Costo de envío']].mean().sort_values('Costo de envío')

plt.figure(figsize=(10, 10))
sns.barplot(y='Producto', x='Costo de envío', data=envios_tienda2, color='#2C6173')
plt.title('Comparación de costo de envio promedio de Productos - Tienda 2')
plt.xlabel('Costo de envio')
plt.ylabel('Productos')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='x') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
envios_tienda3 = tienda3.groupby('Producto')[['Costo de envío']].mean().sort_values('Costo de envío')

plt.figure(figsize=(10, 10))
sns.barplot(y='Producto', x='Costo de envío', data=envios_tienda3, color='#3A9882')
plt.title('Comparación de costo de envio promedio de Productos - Tienda 2')
plt.xlabel('Costo de envio')
plt.ylabel('Productos')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='x') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
envios_tienda4 = tienda4.groupby('Producto')[['Costo de envío']].mean().sort_values('Costo de envío')

plt.figure(figsize=(10, 10))
sns.barplot(y='Producto', x='Costo de envío', data=envios_tienda4, color='#46B955')
plt.title('Comparación de costo de envio promedio de Productos - Tienda 2')
plt.xlabel('Costo de envio')
plt.ylabel('Productos')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='x') # Evita la notación científica en el eje Y
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %% [markdown]
# # Informe final.

# %% [markdown]
# El Sr. Juan llego con la incognita, "Cuál tienda debo vender?" Para poder realizar un analisis completo proporciono sus datos historicos registrados de las cuatro tiendas que posee, en base a esos datos comprimidos en las siguientes categorias:
#
# * Los ingresos totales de las tiendas.
#
# * Las categorías de productos más y menos vendidas.
#
# * Las calificaciones promedio de los clientes por tienda.
#
# * Los productos más y menos vendidos.
#
# * El coste de envío promedio para cada tienda.

# %% [markdown]
# Realizando el estudio del primer punto, el grafico que arrojo demuestra los ingresos de cada tienda, destacando que la ***Tienda 4*** tiene un peor desempeño en ingresos comparado con sus otras tiendas.

# %% [markdown]
# ![comparacion_ingresos_Gbarra.png](data:image/png;base64,...)

# %% [markdown]
# ![comparacion_ingresos_Gpastel.png](data:image/png;base64,...)

# %% [markdown]
# Lo que consideramos el primer punto en tomar en cuenta.
#
#  En la documentacion se pueden encontrar los gráficos realizados para el punto de ***Categorías de productos más y menos vendidos de cada tienda*** ya que tienen valores muy similares, por lo que no fue un valor determinante.

# %% [markdown]
# ![proporcion_ingresos_Gbarraagrup.png](data:image/png;base64,...)

# %% [markdown]
# El siguiente punto a tomar en cuenta es la gráfica obtenida en la codificación de ***calificaciones promedio de clientes por tienda*** ya que la ***Tienda 4*** tiene una de las peores calificaciones.
#
# En sugerencia se aconseja analizar los determinantes de la ***Tienda 1*** ya que es la que más ventas tiene y seria un problema que los clientes dejaran de comprar ya que tienen mala percepción en sus calificaciones.

# %% [markdown]
# ![comparacion_calificacion_Gbarra.png](data:image/png;base64,...)

# %% [markdown]
# El costo del envio tendria un impacto que cambiaria la resolución, sin embargo, este costo es cubierto por el cliente, por lo que no supone un punto determinante.

# %% [markdown]
# ![comparacion_costoenvio_Gbarra.png](data:image/png;base64,...)

# %% [markdown]
# En base a lo anterior desglosado, se aconseja al Sr. Juan ***vender la Tienda 4*** ya que es la que ***menores ingresos genera*** y tiene ***peores calificaciones***

# %% [markdown]
# # Extra

# %%
"""
Utilice los datos de latitud (lat) y longitud (lon) para mapear las ventas de cada
tienda y analizar la distribución geográfica de los productos vendidos.

Genere gráficos de dispersión o mapas de calor (Heatmaps) para visualizar datos e
identificar áreas con la mayor concentración de ventas.

Explore si algunas tiendas tienen un rendimiento superior o inferior al esperado en
determinadas regiones e identifique si existen patrones geográficos que puedan influir
en el rendimiento de las tiendas.
"""

tienda[['lat','lon']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.scatterplot(x='lon', y='lat', data=tienda, hue='Lugar de Compra', s=100, alpha=0.7)
plt.title('Distribución Geográfica de Compras (Tienda 1)')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='lon', y='lat', data=tienda2, hue='Lugar de Compra', s=100, alpha=0.7)
plt.title('Distribución Geográfica de Compras (Tienda 2)')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='lon', y='lat', data=tienda3, hue='Lugar de Compra', s=100, alpha=0.7)
plt.title('Distribución Geográfica de Compras (Tienda 3)')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='lon', y='lat', data=tienda4, hue='Lugar de Compra', s=100, alpha=0.7)
plt.title('Distribución Geográfica de Compras (Tienda 4)')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
